# %% [markdown]
# #Visualize Data for Human Edible Mushroom Species
# '''
# Data_source ='https://www.kaggle.com/uciml/mushroom-classification'
#
# Begin by building an API for obtaining the dataset from Kaggle.com.
#
# Validate data queries before building visual image application layers.
#
# Determine if this dataset is suitable for machine learning models.
#
# Python code source = 'Janani Ravi : Pluralsight'
#
# '''

# %%
# !pip install --upgrade pip

# %%
# !pip3 install seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
print('pandas verision is -->', pd.__version__)
print('seaborn version is -->', sns.__version__)
# Out:
# pandas verision is --> 0.24.0
# seaborn version is --> 0.8.1

# %%
mushroom_data = pd.read_csv('mushrooms.csv')

# %%
mushroom_data.head(7)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8117     p         k           s         e       f    y               f
# 8118     p         k           y         n       f    f               f
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8117            c         n          b  ...                        s
# 8118            c         n          b  ...                        s
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# ...

# %%
mushroom_data.tail(7)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8117     p         k           s         e       f    y               f
# 8118     p         k           y         n       f    f               f
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8117            c         n          b  ...                        s
# 8118            c         n          b  ...                        s
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# ...

# %%
print(len(mushroom_data.index))
# Out:
# 8124

# %%
print(mushroom_data.describe())
mushroom_data.shape
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
mushroom_data.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#class values determine if speices contains human poison
mushroom_data['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
mushroom_data['gill-color'].unique()
# Out:
# array(['k', 'n', 'g', 'p', 'w', 'h', 'u', 'e', 'b', 'r', 'y', 'o'],
#       dtype=object)

# %%
print(mushroom_data.groupby('gill-color').size())
# Out:
# gill-color
# b    1728
# e      96
# g     752
# h     732
# k     408
# n    1048
# o      64
# p    1492
# r      24
# u     492
# w    1202
# y      86
# dtype: int64
